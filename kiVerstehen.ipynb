# %% [markdown]
# # blabla
# Führe einzelne Zellen mit dem Drücken der Tasten SHIFT und ENTER aus. Beachte, dass du zuerst die erste Zelle ausführen musst, damit die Methoden aus der Bibliothek kiVerstehen geladen werden können!

# %%
import kiVerstehen

# %% [markdown]
# # Aufgabe 3
# Passe die Steigung und den y-Achsenabschnitt so an, dass die Kostenfunktion so klein wie möglich wird!

# %%
kiVerstehen.aufgabe3()
# Out:
# interactive(children=(FloatSlider(value=0.3, description='steigung', max=1.0, min=-1.0, step=0.05), FloatSlide…

# %% [markdown]
# # Aufgabe 6
# Passe die Gewichte w1 und w2 und die Biase b1 und b2 so an, dass du die Kosten minimierst und eine möglichst ideale Funktion findest!

# %%
kiVerstehen.aufgabe6()
# Out:
# interactive(children=(FloatSlider(value=-0.5, description='w1', max=1.0, min=-2.0, step=0.05), FloatSlider(val…

# %% [markdown]
# # Aufgabe 9
# Führst du die Methode aus, so wird das Modell mit den Trainingsdaten trainiert. Eine <b>Epoche</b> ist abgeschlossen, wenn alle Trainingsdaten einmal angeschaut wurden und die Gewichte und Biase dementsprechend angepasst wurden. Um die Kostenfunktion weiter zu minimieren und ein gutes Ergebnis zu erhalten, werden einige Epochen benötigt.
# Tipp: Teste einerseits, was passiert wenn du das Modell zweimal mit der selben Anzahl an Epochen trainierst. Teste dann unterschiedliche Anzahlen von Epochen!

# %%
kiVerstehen.aufgabe9(epochen=1000)
# Out:
# Epoche [100/1000], Kosten: 0.6931
# Epoche [200/1000], Kosten: 0.6931
# Epoche [300/1000], Kosten: 0.6931
# Epoche [400/1000], Kosten: 0.6692
# Epoche [500/1000], Kosten: 0.2336
# Epoche [600/1000], Kosten: 0.2125
# Epoche [700/1000], Kosten: 0.2045
# Epoche [800/1000], Kosten: 0.1873
# Epoche [900/1000], Kosten: 0.1998
# Epoche [1000/1000], Kosten: 0.1855

# %% [markdown]
# # Aufgabe 14: Teste die Beispiel-Modelle
# blabla

# %%
import kiVerstehen
projektname='cool oder uncool'
bildname='crocs.jpg'

kiVerstehen.testeBildInModell(projektname,bildname)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Das Bild ist zu 65.25% Cool und zu 34.75% Uncool.
# <PIL.Image.Image image mode=RGB size=243x256>
