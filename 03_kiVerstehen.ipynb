# %% [markdown]
# # kiVerstehen - das interaktive Notebook
# <div>
# <img src="./Grafiken/kiVerstehen-logo2-1.jpg" width="700"/>
# </div>
#
# ## **Teil 3:** Generative KI
# ___

# %% [markdown]
# - Wie funktioniert ChatGPT?
# - wie funktioniert die Bildgenerierung / Musik / ...?

# %%
# %pip install pdfkit, sudo apt install wkhtmltopdf, pip install nbconvert

import pdfkit
# !jupyter nbconvert --to pdf --embed-images 01_kiVerstehen.ipynb
pdfkit.from_file("01_kiVerstehen.html", "01_kiVerstehen.pdf")
# !rm "01_kiVerstehen.html"
# Out:
# [NbConvertApp] Converting notebook 01_kiVerstehen.ipynb to pdf
# [NbConvertApp] Support files will be in 01_kiVerstehen_files/
# [NbConvertApp] Making directory ./01_kiVerstehen_files
# [NbConvertApp] Writing 41660 bytes to notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', 'notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: ['bibtex', 'notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 91286 bytes to 01_kiVerstehen.pdf

# %%
# !pip install pdfkit
