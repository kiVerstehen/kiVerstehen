# %%
from fastbook import *
from fastai.vision.widgets import *

# %%
projektName = 'cool oder uncool'
kategorie1 = 'cool'
kategorie2 = 'uncool'

# %%
#laden der bilder in fns
path = Path(f'Beispiel-Modelle/Trainingsdaten/{projektName}/')
fns = get_image_files(path)
#gibt liste von failed downloaded images
failed = verify_images(fns)
print(f"Es gab {len(failed)} fehlerhafte Downloads. Ich behebe das automatisch!")
#unlink the failed downloaded images
failed.map(Path.unlink)
print(path)
# Out:
# Es gab 0 fehlerhafte Downloads. Ich behebe das automatisch!
# Beispiel-Modelle/Trainingsdaten/cool oder uncool

# %%
daten = DataBlock(
    blocks=(ImageBlock, CategoryBlock), 
    get_items=get_image_files, 
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=Resize(128))
daten

# %%
dls = daten.dataloaders(path)
print(dls.vocab)
# Out:
# ['cool', 'uncool']

# %%
dls.valid.show_batch(max_n=8, nrows=2)

# %%
daten = daten.new(
    item_tfms=RandomResizedCrop(224, min_scale=0.5),
    batch_tfms=aug_transforms())
dls = daten.dataloaders(path)

# %%
learn = vision_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(4)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.518846</td>
#       <td>1.231058</td>
#       <td>0.521739</td>
#       <td>00:02</td>
#     </tr>
#   </tbody>
# </table>
# /home/marcel/.kiVerstehen2/lib/python3.12/site-packages/PIL/Image.py:1043: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /home/marcel/.kiVerstehen2/lib/python3.12/site-packages/PIL/Image.py:1043: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /home/marcel/.kiVerstehen2/lib/python3.12/site-packages/PIL/Image.py:1043: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.810564</td>
#       <td>0.849110</td>
#       <td>0.391304</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.690039</td>
#       <td>0.455462</td>
#       <td>0.195652</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.569759</td>
#       <td>0.264139</td>
#       <td>0.086957</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.488042</td>
#       <td>0.207204</td>
#       <td>0.086957</td>
#       <td>00:02</td>
#     </tr>
#   </tbody>
# </table>
# /home/marcel/.kiVerstehen2/lib/python3.12/site-packages/PIL/Image.py:1043: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /home/marcel/.kiVerstehen2/lib/python3.12/site-packages/PIL/Image.py:1043: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /home/marcel/.kiVerstehen2/lib/python3.12/site-packages/PIL/Image.py:1043: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /home/marcel/.kiVerstehen2/lib/python3.12/site-packages/PIL/Image.py:1043: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /home/marcel/.kiVerstehen2/lib/python3.12/site-packages/PIL/Image.py:1043: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /home/marcel/.kiVerstehen2/lib/python3.12/site-packages/PIL/Image.py:1043: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /home/marcel/.kiVerstehen2/lib/python3.12/site-packages/PIL/Image.py:1043: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /home/marcel/.kiVerstehen2/lib/python3.12/site-packages/PIL/Image.py:1043: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /home/marcel/.kiVerstehen2/lib/python3.12/site-packages/PIL/Image.py:1043: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /home/marcel/.kiVerstehen2/lib/python3.12/site-packages/PIL/Image.py:1043: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(

# %%
#export model as .pkl
learn.export()

# %%
#load pkl-model
learn_inf = load_learner('Beispiel-Modelle/Modelle/cool oder uncool-linux.pkl')

# %%
#predict for image 'blabla.jpeg'
#learn = load_learner('model.pkl')
img = PILImage.create('Beispiel-Modelle/Testbilder/katze.jpg') 
pred,pred_idx,probs = learn_inf.predict(img)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
