# %% [markdown]
# # kiVerstehen - das interaktive Notebook
# <div>
# <img src="./Grafiken/kiVerstehen-logo2-1.jpg" width="700"/>
# </div>
#
# ## **Teil 3:** Generative KI
# ___

# %% [markdown]
# ## Wie geht's?
# Klicke die Zellen mit Linksklick an und führe sie mit dem Drücken der Tasten SHIFT und ENTER oder dem "Run-Button" aus. Teste, ob alles rund läuft mit folgender Zelle.

# %%
2+2
# Out:
# 4

# %% [markdown]
# ## Bevor es losgeht:
# Importiere die kiVerstehen-Bibliothek und wir sind startklar!

# %%
import kiVerstehen

# %% [markdown]
# - Wie funktioniert ChatGPT?

# %% [markdown]
# ___
# ## Aufgabe 1
# **Es war einmal ein...**
# - Du und deine Sitznachbar:in wollt die Geschichte weitererzählen. Hängt abwechselnd jeweils ein Wort an und führt die Erzählung fort bis das Zeitlimit abgelaufen ist. Startet das Zeitlimit mit folgendem Code.
# <div>
# <img src="Grafiken/Sprechblase.png" width="70"/>
# </div>

# %%
kiVerstehen.zeitlimit(minuten=1)

# %% [markdown]
# - Begründet, warum ihr bestimmte Wörter angehängt habt und andere nicht.
# <div>
# <img src="Grafiken/Sprechblase.png" width="70"/>
# </div>

# %% [markdown]
# ___
# So wie ihr beim Erarbeiten eurer Geschichte vorgegangen seid, generieren sogenannte **Transformer** (Sprachmodelle) wie ChatGPT ihre Antworten. Dazu wird der Text (alle Wörter, die schon erzählt wurden) als Eingabe in das Modell gegeben und das Modell errät, welches Wort als nächstes kommt. Dieser Prozess wird wiederholt, bis die gesamte Antwort generiert wurde.

# %% [markdown]
# ___
# ## Aufgabe 2
# Doch woher kennen die Transformer die Bedeutung von einzelnen Wörtern?
#
# Sprachmodelle können nicht sehen, hören, riechen oder fühlen. Daher können sie nicht herausfinden, was sich in der echten Welt wirklich hinter unseren Wörtern verbirgt. Stattdessen lernen sie die Bedeutung der Wörter anhand ihres **Kontexts**, also den Wörtern, die sich in Texten in der Nähe des Wortes befinden.
#
# Interessanterweise besitzen ähnliche Wörter auch einen ähnlichen Kontext. Stell dir vor, du trinkst eine Cola... oder eine Fanta. Bei beiden Worten handelt es sich um ein Getränk und sie besitzen vermutlich daher auch einen ähnlichen Kontext.
#
# - Finde weitere Wörter, die du im gleichen Kontext verwenden würdest.
# <div>
# <img src="Grafiken/schreibaufgabe.png" width="70"/>
# </div>
#
# skip-Gram Modell: Errate das wahrscheinlichste Wort im Kontext.

# %% [markdown]
# ## Aufgabe 3
# Neuronales Netz, dass Kontextwörter errät.
# (um Rechenleistung zu sparen, einfach zählen und Wahrscheinlichkeiten so rausgeben)
#
# -> Schwachsinnsformulator
#
# ## Aufgabe 4
# Word2Vec NICE <--Gewichte W easy peasy + Visualisierung
#
# ## Aufgabe 5
# puzzle teile zusammen setzen irgendwie...

# %% [markdown]
# - wie funktioniert die Bildgenerierung / Musik / ...?
# - Generative KI und Ressourcenverbrauch
# - Urheberrecht

# %% [markdown]
# ## Aufgabe 8
#
# Woher kommen die Trainingsdaten, sind Daten aus dem Internet nicht urheberrechtlich geschützt und was ist mit den Outputs von generativer KI?
#
#
# - Hör dir den Podcast über KI und Urheberrecht an.
#
#
# <audio width="700" height=" "
#        src="Grafiken/240123_0400_Der-KI-Podcast_Darf-KI-einfach-alles-abschreiben"
#        controls>
# </audio>
#
# Quelle: https://www.ardaudiothek.de/episode/der-ki-podcast/darf-ki-einfach-alles-abschreiben/ard/13093793/
#
# - Erörtere deine Meinung zu KI und Urheberrecht.
# <div>
# <img src="Grafiken/schreibaufgabe.png" width="70"/>
# </div>
